# %% [markdown]
# <a href="https://colab.research.google.com/github/valsson-group/UNT-ChemicalApplicationsOfMachineLearning-Spring2026/blob/main/Assignment-5/AlanineDipeptideMolecularVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Alanine Dipeptide Molecular Visualization

# %%
# !pip install py3Dmol

# %%
# !wget https://raw.githubusercontent.com/valsson-group/UNT-ChemicalApplicationsOfMachineLearning-Spring2026/refs/heads/main/Assignment-5/MolecularStructures/AlanineDipeptide-Vacuum-C7eq.mol2
# !wget https://raw.githubusercontent.com/valsson-group/UNT-ChemicalApplicationsOfMachineLearning-Spring2026/refs/heads/main/Assignment-5/MolecularStructures/AlanineDipeptide-Vacuum-C7ax.mol2

# !wget https://raw.githubusercontent.com/valsson-group/UNT-ChemicalApplicationsOfMachineLearning-Spring2026/refs/heads/main/Assignment-5/MolecularStructures/AlanineDipeptide-Vacuum-C7eq.pdb
# !wget https://raw.githubusercontent.com/valsson-group/UNT-ChemicalApplicationsOfMachineLearning-Spring2026/refs/heads/main/Assignment-5/MolecularStructures/AlanineDipeptide-Vacuum-C7ax.pdb

# %%
with open('AlanineDipeptide-Vacuum-C7eq.pdb', 'r') as f:
    pdb_data = f.read()
print(pdb_data)

# %%
print("C7eq Alanine Dipeptide")

import py3Dmol

# view = py3Dmol.view

with open('AlanineDipeptide-Vacuum-C7eq.mol2', 'r') as f:
    pdb_data = f.read()

view = py3Dmol.view()
view.addModel(pdb_data, 'mol2')

view.setStyle("stick")

# view.setStyle({
#             "stick": {"radius": 0.3},     # thicker bonds
#             "sphere": {"scale": 0.25}     # visible atoms
#             })

view.zoomTo()

# view.addLabels("serial")

view.show()

# %%
print("C7ax Alanine Dipeptide")

import py3Dmol

# view = py3Dmol.view

with open('AlanineDipeptide-Vacuum-C7ax.mol2', 'r') as f:
    pdb_data = f.read()

view = py3Dmol.view()
view.addModel(pdb_data, 'mol2')

view.setStyle("stick")

# view.setStyle({
#             "stick": {"radius": 0.3},     # thicker bonds
#             "sphere": {"scale": 0.25}     # visible atoms
#             })

view.zoomTo()

# view.addLabels("serial")

view.show()
